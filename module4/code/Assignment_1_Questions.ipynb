# %% [markdown]
# <a href="https://colab.research.google.com/github/yadavrishikesh/Masterclass-V2-2026/blob/main/module4/code/Assignment_1_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1: Understanding Encoder-Decoder Architectures (U-Net Concept) and Attention Mechanisms

# %% [markdown]
# ## Learning Objectives
# - Understand what an encoder and decoder do.
# - Understand latent representations and skip connections.
# - Understand why U-Net works.
# - Relate attention to human focus, understand intuition behind attention and visualize attention weights.
#
# ## Estimated Completion Time: 30 minutes
#
# ## Background Knowledge Required: Basic Python

# %%
# !pip install torch torchvision matplotlib numpy

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision
import torchvision.transforms as transforms
import numpy as np

# %% [markdown]
# ## Question 1: Encoder-Decoder and U-Net Concept
#
# ### (a) Load and visualize sample images
# Let's use the Fashion-MNIST dataset.

# %%
# TODO: Load FashionMNIST using torchvision.datasets
# TODO: Visualize the first image using matplotlib
# Hint: dataset[0] gives the (image, label) pair.

# %% [markdown]
# ### (b) Create a simple encoder that progressively compresses information

# %%
# TODO: Define a SimpleEncoder class (nn.Module) with 1 Conv2d layer and 1 MaxPool2d layer.
# TODO: Pass the image through the encoder and print the shape of the encoded representation.

# %% [markdown]
# ### (c) Visualize feature maps after encoding

# %%
# TODO: Visualize some of the channels in the latent representation.

# %% [markdown]
# ### (d) Create a decoder that reconstructs the image

# %%
# TODO: Define a SimpleDecoder. You might use nn.Upsample and nn.Conv2d to convert the 14x14x16 map back to 28x28x1.

# %% [markdown]
# ### (e) Compare original, encoded, and reconstructed images

# %%
# TODO: Plot the original, encoded, and reconstructed images side by side.

# %% [markdown]
# ### (f) Reflection: What information is lost during compression?

# %% [markdown]
# > *Write your answer here*

# %% [markdown]
# ### (g) Add a simple skip connection

# %%
# TODO: Define a new model that combines the encoder and decoder.
# TODO: Add a skip connection by concatenating the original input (x) with the decoder's output.

# %% [markdown]
# ### (h) Compare outputs without and with skip connection

# %%
# TODO: Plot and compare the reconstructed image with spatial details recovered via skip connection versus the one without.

# %% [markdown]
# ### (i) Reflection: Why do skip connections help?

# %% [markdown]
# > *Write your answer here*

# %% [markdown]
# ## Question 2: Self-Attention Mechanism
#
# ### (a) Introduce a simple sentence

# %%
# TODO: Define the sentence 'The cat sat on the mat' and convert it to a list of separate words.

# %% [markdown]
# ### (b) Convert words into embeddings

# %%
# TODO: Create dummy random 4-dimensional embeddings for each word in the sentence.

# %% [markdown]
# ### (c) Compute simplified Query, Key, and Value vectors

# %%
# TODO: Compute Q, K, V vectors by multiplying embeddings with random weight matrices (W_q, W_k, W_v).

# %% [markdown]
# ### (d) Calculate attention scores

# %%
# TODO: Calculate attention scores simply as Q multiplied by Key-transpose (scaled dot product).
# TODO: Apply softmax to get attention weights.

# %% [markdown]
# ### (e) Visualize attention matrix as a heatmap

# %%
# TODO: Use matplotlib `matshow` to visualize the `attention_weights` matrix as a heatmap.

# %% [markdown]
# ### (f) Reflection: Interpret the heatmap

# %% [markdown]
# > *Write your answer here*

# %% [markdown]
# ### (g) Experiment: Change one word and observe attention changes

# %%
# TODO: Change the word 'cat' to 'dog', create a new random embedding for it, recalculate attention, and plot.

# %% [markdown]
# ### (h) Reflection: How is attention similar to human focus?

# %% [markdown]
# > *Write your answer here*
