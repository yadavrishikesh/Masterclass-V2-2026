# %% [markdown]
# <a href="https://colab.research.google.com/github/yadavrishikesh/Masterclass-V2-2026/blob/main/module4/slides/Assignment_2_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2: Fine-Tuning Pre-trained Transformer Models

# %% [markdown]
# ## Learning Objectives
# - Understand transfer learning and pre-trained models.
# - Understand fine-tuning.
# - Understand inference vs training.
# - Understand practical Transformer workflows.
#
# ## Estimated Completion Time: 30 minutes
#
# ## Background Knowledge Required: Basic Python

# %%
# !pip install transformers datasets accelerate matplotlib

# %%
import torch
import matplotlib.pyplot as plt
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from datasets import load_dataset

# %% [markdown]
# ## Question 1: Using a Pre-trained Transformer
#
# ### (a) Load a pre-trained transformer
# Let's use `DistilBERT` fine-tuned for sentiment analysis.

# %%
# TODO: Load the 'sentiment-analysis' pipeline from transformers.
# Hint: Use model='distilbert-base-uncased-finetuned-sst-2-english' and return_all_scores=True

# %% [markdown]
# ### (b) Run inference on sample text & (c) Observe predictions

# %%
# TODO: Pass a sample string to the classifier pipeline and print predictions.

# %% [markdown]
# ### (d) Visualize probabilities

# %%
# TODO: Extract the labels and scores from the predictions.
# TODO: Plot a bar chart showing the probabilities.

# %% [markdown]
# ### (e) Test multiple sentences

# %%
# TODO: Write a loop to test inference on at least 3 custom sentences.

# %% [markdown]
# ### (f) Reflection: Why does a model trained by someone else already work?

# %% [markdown]
# > *Write your answer here*

# %% [markdown]
# ### (g) Reflection: Explain transfer learning intuitively

# %% [markdown]
# > *Write your answer here*

# %% [markdown]
# ## Question 2: Fine-Tuning a Transformer
#
# ### (a) Load a small dataset
# Let's use a tiny chunk of the 'dair-ai/emotion' dataset for faster training.

# %%
# TODO: Load the 'emotion' dataset using `load_dataset`.
# Retrieve only the first 200 samples of the 'train' split and 50 of 'validation'.

# %% [markdown]
# ### (b) Explore class labels

# %%
# TODO: Extract and print the unique label names available in the dataset (features['label'].names).

# %% [markdown]
# ### (c) Fine-tune DistilBERT on a small subset

# %%
# TODO: Load 'distilbert-base-uncased' tokenizer and model. Remember we have 6 labels here.
# TODO: Tokenize the datasets using a padding strategy.
# TODO: Setup TrainingArguments and run Trainer.train() to fine-tune the model.

# %% [markdown]
# ### (d) Track training loss & (e) Plot training progress

# %%
# TODO: Extract logging history from trainer.state.log_history
# TODO: Plot the loss curve over the training steps.

# %% [markdown]
# ### (f) Evaluate performance & (g) Compare: Before vs After fine-tuning

# %%
# TODO: Run the freshly fine-tuned model on a sample string, e.g., 'I feel so incredibly lost and sad today.'
# Compare what an untrained head vs trained head would predict.

# %% [markdown]
# ### (h) Reflection: What knowledge did the model already have?

# %% [markdown]
# > *Write your answer here*

# %% [markdown]
# ### (i) Reflection: What new knowledge did fine-tuning add?

# %% [markdown]
# > *Write your answer here*
