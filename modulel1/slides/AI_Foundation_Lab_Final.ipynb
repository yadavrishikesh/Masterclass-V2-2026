# %% [markdown]
# <a href="https://colab.research.google.com/github/yadavrishikesh/Masterclass-V2-2026/blob/main/modulel1/slides/AI_Foundation_Lab_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Foundations for AI: Hands-On Lab Session
# **Author:** Dr. Rishikesh Yadav / Vedant Vibhor
#
# **Context:** Instead of looking at tiny 5-row DataFrames, today we will analyze a **real-world dataset**: [Student Performance](http://archive.ics.uci.edu/dataset/320/student+performance) from a Portuguese secondary school.
#
# **Objective:** Predict student final grades (`G3`) based on their habits, demographics, and school life, moving from basic NumPy all the way to Neural Networks.
#
# **Instructions:**
# - Complete all `# TODO` sections.
# - Discuss the "Discussion" questions with your group.
#
# ### Learning Outcomes
# By the end of this lab you should be able to:
# - Perform matrix operations using NumPy
# - Explore datasets with Pandas
# - Visualize relationships using Matplotlib and Seaborn
# - Build preprocessing pipelines
# - Train regression and classification models
# - Evaluate models using RMSE, F1 and ROC-AUC
# - Build a neural network using TensorFlow

# %% [markdown]
# ---
# ### Part 0: Environment Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ML Tools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, f1_score, roc_auc_score, confusion_matrix, classification_report
from sklearn.compose import ColumnTransformer

# Deep Learning
import tensorflow as tf

# Settings
sns.set_theme(style="whitegrid")
np.random.seed(42)
tf.random.set_seed(42)
# %matplotlib inline

# %% [markdown]
# ---
# ### Part 1: NumPy Warm-up
# *Before we touch Pandas, let's ensure our matrix math is solid.*

# %%
# Simulating a batch of 3 students with 2 features: [Hours Studied, Sleep Hours]
X_batch = np.array([
    [4, 8],
    [8, 6],
    [2, 9]
])

# Weights learned by a model: [Weight for Hours, Weight for Sleep]
weights = np.array([2.5, 0.5])
bias = 5.0

# TODO 1:
# Calculate the predicted score for each student using Matrix Multiplication and adding bias
# Hint: Look at the "NumPy in Action" slide from the lecture
predictions = None

print("Predictions:", predictions)

# %% [markdown]
# ---
# ### Part 2: Data Loading & Pandas Profiling
# *We will use the [Student Performance dataset from UCI](http://archive.ics.uci.edu/dataset/320/student+performance). The data is separated by semicolons.*

# %%
# URL for the dataset
url = "https://raw.githubusercontent.com/KunjalJethwani/StudentPerformance/refs/heads/main/student-mat.csv"



# TODO 2: Read the CSV into a DataFrame called `df`
df = None

# %%
# TODO 3: Display the first 3 rows, the shape, and the info of the dataframe

# %%
# TODO 4: Generate descriptive statistics for the numerical columns

# %% [markdown]
# #### Feature Engineering
# Let's create meaningful categories.

# %%
# TODO 5: Create a new column called 'Pass' which is 1 if 'G3' (final grade) >= 10, else 0
df['Pass'] = None

# TODO 6: What is the average final grade (G3) for students who pass vs those who fail?
# Hint: Use groupby

# %% [markdown]
# ---
# ### Part 3: Exploratory Data Analysis (Visualization)
# *Don't just plot—interpret.*

# %%
# TODO 7: Create a Figure with 1 row, 2 columns
# Plot 1: A histogram of the final grades ('G3')
# Plot 2: A scatter plot of 'absences' vs 'G3' colored by 'Pass' (use hue='Pass')
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# %% [markdown]
# **Discussion:** Looking at the histogram, is the distribution of grades normal (bell curve)? What does this imply for modeling?

# %%
# TODO 8: Select only the numeric columns and plot a Correlation Heatmap.
# Which feature is most positively correlated with G3?

# %% [markdown]
# #### Additional Visualization
# Let's look at how the final grade separates between passing and failing students.

# %%
# TODO 8b: Create a boxplot comparing Pass vs G3.
# sns.boxplot(x='Pass', y='G3', data=df)
# plt.title("Final Grade Distribution: Pass vs Fail")
# plt.show()

# %% [markdown]
# #### Human Prediction Challenge
# Before we let the machine learn, try to use your intuition.
# Predict the final grade (G3) of a student with:
# - studytime = 4
# - absences = 2
# - failures = 0
# - schoolsup = yes
# - famsup = no
#
# *Write your guess here as a comment:*

# %%
# My guess for G3 is:

# %% [markdown]
# ---
# ### Part 4: Data Preprocessing Pipeline
# *Real data has text categories. Models only take numbers.*

# %%
# For simplicity, let's select a mix of numeric and categorical features
features = ['studytime', 'traveltime', 'age' ,'failures', 'Medu', 'schoolsup', 'famsup']
X = df[features]
y_reg = df['G3']       # Target for Regression
y_clf = df['Pass']     # Target for Classification

# TODO 9: Split the data into Training (80%) and Testing (20%) sets
# We do this twice to ensure the exact same rows are used for both regression and classification
X_train, X_test, y_reg_train, y_reg_test = train_test_split(X, y_reg, test_size=0.2, random_state=42)
_, _, y_clf_train, y_clf_test = train_test_split(X, y_clf, test_size=0.2, random_state=42)

# %%
# We must scale numbers and one-hot encode text.
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['studytime', 'traveltime', 'age', 'failures', 'Medu']),
        ('cat', OneHotEncoder(drop='first'), ['schoolsup', 'famsup'])
    ])

# Fit and transform the training data
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)

print("Processed shape:", X_train_processed.shape) # Should be (samples, 5 features)

# %% [markdown]
# ---
# ### Part 5: Supervised Learning - Regression
# *Can we predict the exact grade?*

# %%
# TODO 10: Initialize and train a Linear Regression model on the processed data
reg_model = None

# %%
# TODO 11: Predict on the test set and calculate RMSE and R^2 Score
# Hint: RMSE = sqrt(mean_squared_error)
print("RMSE:", None)
print("R^2 Score:", None)

# %% [markdown]
# **Discussion:** An R^2 of ~0.1 is typical for this dataset using simple features. Human behavior is hard to predict! What features could we add to improve this?

# %% [markdown]
# #### Baseline Model Exercise
# Before celebrating our Linear Regression model, we must establish a baseline.
# The dumbest model possible just predicts the average grade of the training set for every student.

# %%
# TODO 11b: Create a baseline predictor that always predicts the mean training grade.
# Calculate its RMSE and compare it with your Linear Regression RMSE.
baseline_pred = None # Hint: use y_reg_train.mean()
baseline_rmse = None # Hint: np.sqrt(mean_squared_error(y_reg_test, baseline_pred))

print(f"Baseline RMSE (Predicting Mean): {baseline_rmse:.2f}")
# print(f"Linear Regression RMSE: {None:.2f}") # Uncomment and fill in your previous RMSE here

# %% [markdown]
# #### Feature Importance Exercise
# Since we used a linear model, we can look at the coefficients to see what the model learned.

# %%
# TODO 11c: Print reg_model.coef_ paired with the feature names.
# Hint: Get the feature names using preprocessor.get_feature_names_out()
# Which feature has the biggest positive impact on the final grade?

# %% [markdown]
# ---
# ### Part 6: Supervised Learning - Classification
# *Can we predict if a student will Pass or Fail?*

# %%
# TODO 12: Initialize and train a Logistic Regression model
# (Ensure you use the classification targets: y_clf_train)
clf_model = None

# %%
# TODO 13: Generate predictions (classes, not probabilities) for the test set
clf_preds = None

# TODO 14: Print the Classification Report and Confusion Matrix
print("Classification Report:")
print(None)

print("\nConfusion Matrix:")
print(None)

# %%
# TODO 15: To calculate ROC-AUC, we need PROBABILITIES, not hard classes.
# Get prediction probabilities for class 1, then calculate roc_auc_score
clf_probs = None
print("ROC-AUC Score:", None)

# %% [markdown]
# #### Evaluation Reflection
# Look at your Confusion Matrix from TODO 14.
# Why might **Recall** be more important than Accuracy for a school trying to identify at-risk students?
#
# *Write your thoughts here as a comment:*

# %%
# Recall is more important because...

# %% [markdown]
# ---
# ### Part 7: TensorFlow Neural Network
# *Let's see if a non-linear model beats Linear Regression.*

# %%
# Build a simple Neural Network for REGRESSION
nn_model = tf.keras.Sequential([
    # TODO 16: Add a Dense hidden layer with 5 units and 'relu' activation. Then add another Dense hidden layer with 2 units and 'leaky_relu' activation.
    tf.keras.layers.Dense(None),
    tf.keras.layers.Dense(None),

    # TODO 17: Add a Dense output layer with 1 unit (no activation for regression)
    tf.keras.layers.Dense(None)
])

# TODO 18: Compile the model (optimizer='adam', loss='mse', metrics=['mae'])

# %%
# TODO 19: Train the model for 100 epochs
# Use validation_split=0.2 inside the fit function
history = None

# %%
# Plotting the training loss (Learning Curve)
plt.plot(history.history['loss'], label='Train Loss (MSE)')
plt.plot(history.history['val_loss'], label='Val Loss (MSE)')
plt.legend()
plt.title("Neural Network Training History")
plt.show()

# %% [markdown]
# #### Neural Network Reflection
# Look at the plot above:
# 1. Is training loss decreasing?
# 2. Is validation loss decreasing?
# 3. Is there a gap between them? If yes, the model might be overfitting.

# %%
# TODO 20: Evaluate the Neural Network on X_test_processed
# Calculate RMSE and compare it to your Linear Regression RMSE from Part 5.
nn_preds = None
print("NN RMSE:", None)

# %% [markdown]
# ### Model Comparison Summary
#
# Fill in the table after completing all sections.
#
# | Model | Metric | Value |
# |---------|---------|---------|
# | Baseline | RMSE | |
# | Linear Regression | RMSE | |
# | Linear Regression | R² | |
# | Logistic Regression | F1 | |
# | Logistic Regression | ROC-AUC | |
# | Neural Network | RMSE | |
#
# #### Discussion
# 1. Which model performed best?
# 2. Did the neural network outperform linear regression?
# 3. Which metric was most informative?

# %% [markdown]
# ---
# ### Part 8: Bonus Challenge
#
# Neural networks are powerful because of hidden layers and non-linear activations.
# Your task: Beat the Logistic Regression F1-Score using a Neural Network for the **Classification** task.

# %%
# TODO BONUS:
# 1. Build a NEW neural network for classification (predicting 'Pass').
#    - Add three Dense hidden layer (e.g., 5 units, 3 units, then 2 units, all 'relu').
#    - Change the output layer to have 1 unit with a 'sigmoid' activation.
# 2. Compile it with loss='binary_crossentropy' and metrics=['accuracy'].
# 3. Train it for 100 epochs.
# 4. Evaluate it on the test set: Print out the F1 Score and ROC-AUC.
# 5. Did it beat the Logistic Regression model?

# %% [markdown]
# ### Data Leakage Discussion
#
# Suppose you were allowed to use:
#
# - G1 (first period grade)
# - G2 (second period grade)
#
# to predict G3.
#
# #### Questions
# 1. Would model performance improve?
# 2. Would this be useful if the goal is to identify struggling students early?
# 3. Why can some features create data leakage?

# %% [markdown]
# ### Recall vs Accuracy
#
# The school wants to identify students at risk of failing.
#
# Which metric is more important?
#
# - Accuracy
# - Precision
# - Recall
# - F1 Score
#
# Explain your reasoning and discuss the consequences of False Negatives.

# %% [markdown]
# ### Neural Network Parameter Counting
#
# After running:
#
# ```python
# nn_model.summary()
# ```
#
# Answer:
#
# 1. How many trainable parameters does the network have?
# 2. Can you manually verify the count using:
#
# Parameters = Weights + Biases
#
# 3. How does adding more hidden units affect the parameter count?

# %% [markdown]
# ### Final Reflection
#
# 1. Which preprocessing step had the largest impact?
# 2. Which feature appeared most predictive?
# 3. What did you learn about model evaluation?
# 4. When would you choose a simpler model over a neural network?
# 5. What is one improvement you would make to this project?
